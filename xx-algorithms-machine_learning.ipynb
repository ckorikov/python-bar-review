# %% [markdown]
# # Алгоритмы. Машинное обучение

# %% [markdown]
# **Машинное обучение** — способ решеия вычислительных задач без явного программирования.
#
# Алгоритмы машинного обучения решают два класса задач:
# - классификация — разбиение по категориям,
# - регрессия — предсказание численного результата.

# %% [markdown]
# ## 1. Метод ближайших k ближайших соседей
#
# [k-nearest neighbors algorithm](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm)
